# %% [markdown]
# <a href="https://colab.research.google.com/github/shahmoksheet/sustainable-energy/blob/main/Week2_Global_Energy_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# For tables
from IPython.display import display, Markdown

# %%
data = {
    'Energy Type': ['Solar (PV)', 'Wind', 'Hydropower', 'Biomass', 'Geothermal', 'Hydrogen (Fuel Cells)'],
    'Efficiency (%)': ['15–22%', '45–50%', '85–90%', '20–40%', '10–20% (electric), 70% (heat)', '>60%'],
    'Pros': [
        'Simple, scalable, quiet',
        'High efficiency, low cost',
        'Very high efficiency, reliable',
        'Flexible feedstock, dispatchable',
        'Stable baseload, low emissions',
        'High energy density, zero emissions'
    ],
    'Cons': [
        'Intermittent, manufacturing impact',
        'Visual impact, variable output',
        'Environmental disruption',
        'Land use, variable emissions',
        'Location-limited, initial cost',
        'High cost, infrastructure challenges'
    ]
}
df_compare = pd.DataFrame(data)
display(df_compare)
# Out:
#              Energy Type                 Efficiency (%)  \
# 0             Solar (PV)                         15–22%
# 1                   Wind                         45–50%
# 2             Hydropower                         85–90%
# 3                Biomass                         20–40%
# 4             Geothermal  10–20% (electric), 70% (heat)
# 5  Hydrogen (Fuel Cells)                           >60%
#
#                                   Pros                                  Cons
# 0              Simple, scalable, quiet    Intermittent, manufacturing impact
# 1            High efficiency, low cost        Visual impact, variable output
# 2       Very high efficiency, reliable              Environmental disruption
# 3     Flexible feedstock, dispatchable          Land use, variable emissions
# 4       Stable baseload, low emissions        Location-limited, initial cost
# 5  High energy density, zero emissions  High cost, infrastructure challenges

# %%
# Simplified numeric mapping for visualization
eff_map = {
    'Solar (PV)': 18, 'Wind': 48, 'Hydropower': 88,
    'Biomass': 30, 'Geothermal': 15, 'Hydrogen (Fuel Cells)': 62
}
plt.figure(figsize=(8,5))
sns.barplot(x=list(eff_map.keys()), y=list(eff_map.values()), hue=list(eff_map.keys()), palette='viridis', legend=False)
plt.xticks(rotation=45, ha='right')
plt.ylabel('Efficiency (%)')
plt.title('Efficiency Comparison of Renewable Energy Types')
plt.tight_layout()
plt.show()

# %%
hydrogen_data = {
    'Year': [2023, 2024, 2025],
    'Global H₂ Production (million tonnes)': [97, 100, 105],
    'Low-emission H₂ Share (million tonnes)': [1, None, None]
}
pd.DataFrame(hydrogen_data)
# Out:
#    Year  Global H₂ Production (million tonnes)  \
# 0  2023                                     97
# 1  2024                                    100
# 2  2025                                    105
#
#    Low-emission H₂ Share (million tonnes)
# 0                                     1.0
# 1                                     NaN
# 2                                     NaN

# %%
### Hydrogen Deep Dive: Why It Stands Out

**Pros:**
- Extremely **high energy density**, outperforming fossil fuels (~120 MJ/kg) :contentReference[oaicite:7]{index=7}.
- **High efficiency**: Fuel cells up to ~65%, vs. ~35% for traditional plants :contentReference[oaicite:8]{index=8}.
- **Zero direct emissions** when produced cleanly :contentReference[oaicite:9]{index=9}.
- **Storage & transport flexibility**: ideal for long-term energy storage and remote applications.

**Cons:**
- **High initial production and infrastructure cost**, still above other renewables :contentReference[oaicite:10]{index=10}.
- **Storage challenges**: hydrogen is flammable, challenging to store and transport safely :contentReference[oaicite:11]{index=11}.
- **Regulatory barriers**: standards and frameworks are still evolving :contentReference[oaicite:12]{index=12}.
# Out:
#   File "/tmp/ipython-input-2291916156.py", line 3
#     **Pros:**
#     ^
# SyntaxError: invalid syntax

# %%
**Conclusion & Week-3 Focus**

After analyzing multiple renewable sources, hydrogen emerges as the most promising for Week 3 because:
- It offers *highest efficiency and energy density*.
- It plays a pivotal role in *long-duration storage* and *hard-to-decarbonize sectors*.
- *Policy momentum and cost trends* signal its future scalability.

**Next:** In Week 3, I will develop either:
- A **predictive model** of hydrogen cost trends, or
- A **roadmap visualization** for green hydrogen adoption (global + India).

# %% [markdown]
# ### Hydrogen Deep Dive: Why It Stands Out
#
# **Pros:**
# - Extremely **high energy density**, outperforming fossil fuels (~120 MJ/kg) :contentReference[oaicite:7]{index=7}.
# - **High efficiency**: Fuel cells up to ~65%, vs. ~35% for traditional plants :contentReference[oaicite:8]{index=8}.
# - **Zero direct emissions** when produced cleanly :contentReference[oaicite:9]{index=9}.
# - **Storage & transport flexibility**: ideal for long-term energy storage and remote applications.
#
# **Cons:**
# - **High initial production and infrastructure cost**, still above other renewables :contentReference[oaicite:10]{index=10}.
# - **Storage challenges**: hydrogen is flammable, challenging to store and transport safely :contentReference[oaicite:11]{index=11}.
# - **Regulatory barriers**: standards and frameworks are still evolving :contentReference[oaicite:12]{index=12}.

# %% [markdown]
# **Conclusion & Week-3 Focus**
#
# After analyzing multiple renewable sources, hydrogen emerges as the most promising for Week 3 because:
# - It offers *highest efficiency and energy density*.
# - It plays a pivotal role in *long-duration storage* and *hard-to-decarbonize sectors*.
# - *Policy momentum and cost trends* signal its future scalability.
#
# **Next:** In Week 3, I will develop either:
# - A **predictive model** of hydrogen cost trends, or
# - A **roadmap visualization** for green hydrogen adoption (global + India).
